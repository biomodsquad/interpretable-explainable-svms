# %% [markdown]
# # Ensemble-pooled stochastic search
#
# This experiment starts from the fixed-stratified five-member forward-knee
# baseline and tests `ensemble_stochastic_feature_selection`. Candidate moves
# from all models are ranked in one global pool by their estimated effect on the
# aggregate out-of-fold ensemble prediction. The search uses a 500-step maximum
# and convergence patience of 50.

# %%
from pathlib import Path
import copy
import sys
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score, balanced_accuracy_score, f1_score, roc_auc_score
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

repo_root = next(
    path for path in [Path.cwd(), *Path.cwd().parents]
    if (path / "mistic" / "svmSet.py").exists()
)
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from mistic import combined_rank, cvSet, kernelWrapper, paramSet, score_svc, svmSet

sns.set_theme(style="whitegrid", context="notebook")
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Fixed experimental design
#
# - 500 observations and 100 predictors: 10 informative, 10 redundant, and 80 noise.
# - One stratified 25% blind set, withheld before every preprocessing and modeling step.
# - Three inner seeds and exactly five SVM-set members.
# - Fifteen percent of the outer-training rows are reserved for ensemble-level validation and excluded from all member CV splits.
# - `combined_rank(weight=0.75)`, separate feature sets, and separate parameters.
# - Forward search uses the 20-medoid singleton screen and a 20-feature maximum.
# - Backward search uses scaled gamma during search and final full-grid retuning.
# - Greedy selection returns the knee-selected subset before refinement.
# - Stochastic variants start from identical deep copies of that subset. Every iteration budget uses the same seed. Both single-model proposals and joint all-model proposals are tested.
# - Each sklearn unified-feature reference uses only the top `knee_feature_count`
#   features according to the corresponding ensemble's unified rank.

# %%
N_SAMPLES = 500
N_FEATURES = 100
N_INFORMATIVE = 10
N_REDUNDANT = 10
SIGNAL_FEATURES = set(range(N_INFORMATIVE + N_REDUNDANT))

X_values, y_values = make_classification(
    n_samples=N_SAMPLES,
    n_features=N_FEATURES,
    n_informative=N_INFORMATIVE,
    n_redundant=N_REDUNDANT,
    n_repeated=0,
    n_classes=2,
    weights=[0.55, 0.45],
    class_sep=1.0,
    flip_y=0.03,
    shuffle=False,
    random_state=2026,
)
X = pd.DataFrame(X_values)
y = pd.Series(y_values, name="class")

MODEL_COUNTS = [5]
REFINEMENT_STEPS = [0, 10, 20, 50, 100]
SELECTION_STRATEGIES = ["forward_knee", "backward_knee"]
INNER_SEEDS = list(range(3))
BLIND_SET_SEED = 42
TEST_SIZE = 0.25
INNER_VALIDATION_SIZE = 0.20
ENSEMBLE_VALIDATION_SIZE = 0.15
RANK_WEIGHT = 0.75
FORWARD_MAX_FEATURES = 20
C_VALUES = [0.25, 1.0, 4.0]
GAMMA_VALUES = [2.0 ** exponent for exponent in (-9, -7, -5)]

X_train, X_blind, y_train, y_blind = train_test_split(
    X, y, test_size=TEST_SIZE, stratify=y, random_state=BLIND_SET_SEED
)
print(f"Training rows: {len(X_train)}; fixed blind rows: {len(X_blind)}")
# Out:
# Training rows: 375; fixed blind rows: 125

# %%
def parameter_grid():
    return [
        paramSet(model={"C": cost}, kernel={"gamma": gamma})
        for cost in C_VALUES for gamma in GAMMA_VALUES
    ]


def metric_row(y_true, predictions, decision_values):
    return {
        "roc_auc": roc_auc_score(y_true, decision_values),
        "f1": f1_score(y_true, predictions),
        "balanced_accuracy": balanced_accuracy_score(y_true, predictions),
        "accuracy": accuracy_score(y_true, predictions),
    }


def fit_sklearn_reference(X_train_subset, y_train, seed):
    pipeline = Pipeline([
        ("scale", StandardScaler()),
        ("svc", SVC(kernel="rbf", class_weight="balanced")),
    ])
    search = GridSearchCV(
        pipeline,
        {"svc__C": C_VALUES, "svc__gamma": GAMMA_VALUES},
        scoring="roc_auc",
        cv=StratifiedKFold(n_splits=4, shuffle=True, random_state=seed),
        n_jobs=-1,
        refit=True,
    )
    return search.fit(X_train_subset, y_train)


def fit_knee_ensemble(strategy, num_models, seed):
    scaler = StandardScaler().fit(X_train)
    X_scaled = scaler.transform(X_train)
    splits = cvSet(
        X_scaled,
        np.asarray(y_train),
        num_feature_medoids=20,
        ensemble_validation_size=ENSEMBLE_VALIDATION_SIZE,
        ensemble_validation_random_seed=50_000,
        ensemble_validation_stratify=True,
    )
    splits.classification(
        num_sets=num_models,
        validation_size=INNER_VALIDATION_SIZE,
        random_seed=seed,
    )
    ensemble = svmSet(
        SVC(kernel="precomputed", class_weight="balanced"),
        splits,
        score_method=score_svc(weight=1.0).score,
        kernel=kernelWrapper(type="rbf"),
        separate_feature_sets=True,
        separate_parameters=True,
    )
    options = dict(
        parameter_grid=parameter_grid(),
        feature_ranker=combined_rank(weight=RANK_WEIGHT).compute,
        set_for_rank="sample",
        tune_models_each_step=False,
        post_find_knee=True,
    )
    if strategy == "forward_knee":
        ensemble.greedy_forward_selection(
            reduction_factor=0,
            max_features=FORWARD_MAX_FEATURES,
            **options,
        )
    else:
        ensemble.greedy_backward_selection(reduction_factor=0.1, **options)
    return scaler, ensemble, ensemble.find_knee(metric="score")


def ranked_unified_features(ensemble, limit):
    unified_set = set(np.asarray(ensemble.unified_features, dtype=int))
    ranked = np.asarray([
        feature for feature in ensemble.unified_sorted_features
        if feature in unified_set
    ], dtype=int)
    return ranked[:min(int(limit), len(ranked))]


def recovery(features):
    features = np.asarray(features, dtype=int)
    signal_count = len(set(features).intersection(SIGNAL_FEATURES))
    return signal_count / len(SIGNAL_FEATURES), 1 - signal_count / len(features)


def ensemble_row(ensemble, scaler, seed, strategy, num_models, steps, knee_count, update_all_models):
    X_blind_scaled = scaler.transform(X_blind)
    predictions = ensemble.predict(X_blind_scaled)
    decisions = ensemble.decision_function(X_blind_scaled)
    unified = np.asarray(ensemble.unified_features, dtype=int)
    top20 = ranked_unified_features(ensemble, 20)
    signal_recall, noise_fraction = recovery(top20)
    member_predictions = np.column_stack([
        ensemble.predict(X_blind_scaled, model_index=i) for i in range(num_models)
    ])
    disagreement = np.mean([
        np.mean(member_predictions[:, i] != member_predictions[:, j])
        for i in range(num_models) for j in range(i + 1, num_models)
    ]) if num_models > 1 else 0.0
    history = getattr(ensemble, "stochastic_performance_", [])
    return {
        "seed": seed,
        "method": "MiSTIC SVM set",
        "selection_strategy": strategy,
        "refinement_steps": steps,
        "update_all_models": update_all_models,
        "refinement_objective": "ensemble_validation" if steps else "knee_baseline",
        "num_models": num_models,
        "knee_feature_count": knee_count,
        "num_unified_features": len(unified),
        "signal_recall": signal_recall,
        "noise_fraction": noise_fraction,
        "member_disagreement": disagreement,
        "accepted_moves": sum(row.accepted for row in history),
        **metric_row(y_blind, predictions, decisions),
    }


def reference_row(ensemble, seed, strategy, num_models, steps, knee_count, update_all_models):
    features = ranked_unified_features(ensemble, knee_count)
    signal_recall, noise_fraction = recovery(features)
    reference = fit_sklearn_reference(X_train.iloc[:, features], y_train, seed)
    return {
        "seed": seed,
        "method": "sklearn on knee-ranked unified features",
        "selection_strategy": strategy,
        "refinement_steps": steps,
        "update_all_models": update_all_models,
        "refinement_objective": "ensemble_validation" if steps else "knee_baseline",
        "num_models": num_models,
        "knee_feature_count": knee_count,
        "num_unified_features": len(features),
        "signal_recall": signal_recall,
        "noise_fraction": noise_fraction,
        "member_disagreement": 0.0,
        "accepted_moves": np.nan,
        **metric_row(
            y_blind,
            reference.predict(X_blind.iloc[:, features]),
            reference.decision_function(X_blind.iloc[:, features]),
        ),
    }

# %% [markdown]
# ## Run the comparison
#
# For each seed and selection direction, the two refined conditions begin from
# independent copies of the same knee-selected ensemble. Refinement retunes every
# proposal with the same parameter grid used by the greedy search.

# %%
rows = []
history_rows = []
strategy = "forward_knee"
num_models = 5
max_steps = 500
for seed in INNER_SEEDS:
    scaler, base_ensemble, knee_count = fit_knee_ensemble(
        strategy, num_models, seed
    )
    candidate = copy.deepcopy(base_ensemble)
    candidate.ensemble_stochastic_feature_selection(
        parameter_grid(),
        n_iterations=max_steps,
        temperature=0.05,
        cooling_rate=0.97,
        add_probability=0.5,
        random_seed=10_000 + 100 * num_models + seed,
        convergence_patience=50,
    )
    rows.append(ensemble_row(
        candidate, scaler, seed, strategy, num_models,
        candidate.ensemble_stochastic_iterations_, knee_count, False,
    ))
    rows[-1].update({
        "method": "MiSTIC ensemble-pooled search",
        "search_max_steps": max_steps,
        "iterations_run": candidate.ensemble_stochastic_iterations_,
        "converged": candidate.ensemble_stochastic_converged_,
        "stop_reason": candidate.ensemble_stochastic_stop_reason_,
        "search_best_score": candidate.ensemble_stochastic_best_score_,
        "accepted_moves": sum(
            record.accepted for record in candidate.ensemble_stochastic_performance_
        ),
    })
    rows.append(reference_row(
        candidate, seed, strategy, num_models,
        candidate.ensemble_stochastic_iterations_, knee_count, False,
    ))
    rows[-1].update({
        "selection_strategy": "forward_knee_ensemble_pooled",
        "search_max_steps": max_steps,
        "iterations_run": candidate.ensemble_stochastic_iterations_,
        "converged": candidate.ensemble_stochastic_converged_,
        "stop_reason": candidate.ensemble_stochastic_stop_reason_,
        "search_best_score": candidate.ensemble_stochastic_best_score_,
    })
    best_score = candidate.ensemble_stochastic_performance_[0].score
    for record in candidate.ensemble_stochastic_performance_:
        if record.accepted:
            best_score = max(best_score, record.score)
        history_rows.append({
            "seed": seed,
            "step": record.iteration + 1,
            "estimated_score": record.estimated_score,
            "actual_score": record.score,
            "accepted": record.accepted,
            "best_score": best_score,
            "pool_size": record.pool_size,
            "temperature": record.temperature,
        })
    print(
        f"completed seed={seed}; iterations={candidate.ensemble_stochastic_iterations_}; "
        f"stop={candidate.ensemble_stochastic_stop_reason_}"
    )

pooled_results = pd.DataFrame(rows)
pooled_history = pd.DataFrame(history_rows)
pooled_results.to_csv(
    repo_root / "validation/Synthetic100_svmSet_forward_ensemble_pooled_search_results.csv",
    index=False,
)
pooled_history.to_csv(
    repo_root / "validation/Synthetic100_svmSet_forward_ensemble_pooled_search_history.csv",
    index=False,
)
pooled_results
# Out:
# Number of Features: 1, Score: 0.648
# Number of Features: 2, Score: 0.667
# Number of Features: 3, Score: 0.682
# Number of Features: 4, Score: 0.697
# Number of Features: 5, Score: 0.684
# Number of Features: 6, Score: 0.678
# Number of Features: 7, Score: 0.712
# Number of Features: 8, Score: 0.701
# Number of Features: 9, Score: 0.711
# Number of Features: 10, Score: 0.717
# Number of Features: 11, Score: 0.709
# Number of Features: 12, Score: 0.709
# Number of Features: 13, Score: 0.709
# Number of Features: 14, Score: 0.710
# Number of Features: 15, Score: 0.710
# Number of Features: 16, Score: 0.702
# Number of Features: 17, Score: 0.724
# Number of Features: 18, Score: 0.727
# Number of Features: 19, Score: 0.733
# Number of Features: 20, Score: 0.726
# Number of Features: 100, Score: 0.728
# completed seed=0; iterations=129; stop=converged
# Number of Features: 1, Score: 0.683
# Number of Features: 2, Score: 0.673
# Number of Features: 3, Score: 0.707
# Number of Features: 4, Score: 0.714
# Number of Features: 5, Score: 0.728
# Number of Features: 6, Score: 0.743
# Number of Features: 7, Score: 0.729
# Number of Features: 8, Score: 0.714
# Number of Features: 9, Score: 0.748
# Number of Features: 10, Score: 0.751
# Number of Features: 11, Score: 0.752
# Number of Features: 12, Score: 0.755
# Number of Features: 13, Score: 0.750
# Number of Features: 14, Score: 0.746
# Number of Features: 15, Score: 0.733
# Number of Features: 16, Score: 0.732
# Number of Features: 17, Score: 0.734
# Number of Features: 18, Score: 0.733
# Number of Features: 19, Score: 0.731
# Number of Features: 20, Score: 0.732
# Number of Features: 100, Score: 0.736
# completed seed=1; iterations=67; stop=converged
# Number of Features: 1, Score: 0.600
# Number of Features: 2, Score: 0.637
# Number of Features: 3, Score: 0.690
# Number of Features: 4, Score: 0.703
# Number of Features: 5, Score: 0.724
# Number of Features: 6, Score: 0.720
# Number of Features: 7, Score: 0.717
# Number of Features: 8, Score: 0.713
# Number of Features: 9, Score: 0.709
# Number of Features: 10, Score: 0.744
# Number of Features: 11, Score: 0.746
# Number of Features: 12, Score: 0.741
# Number of Features: 13, Score: 0.753
# Number of Features: 14, Score: 0.757
# Number of Features: 15, Score: 0.749
# Number of Features: 16, Score: 0.749
# Number of Features: 17, Score: 0.766
# Number of Features: 18, Score: 0.760
# Number of Features: 19, Score: 0.756
# Number of Features: 20, Score: 0.759
# Number of Features: 100, Score: 0.750
# completed seed=2; iterations=500; stop=max_iterations
#    seed                                   method  \
# 0     0            MiSTIC ensemble-pooled search
# 1     0  sklearn on knee-ranked unified features
# 2     1            MiSTIC ensemble-pooled search
# 3     1  sklearn on knee-ranked unified features
# 4     2            MiSTIC ensemble-pooled search
# 5     2  sklearn on knee-ranked unified features
#
#              selection_strategy  refinement_steps  update_all_models  \
# 0                  forward_knee               129              False
# 1  forward_knee_ensemble_pooled               129              False
# 2                  forward_knee                67              False
# 3  forward_knee_ensemble_pooled                67              False
# 4                  forward_knee               500              False
# 5  forward_knee_ensemble_pooled               500              False
#
#   refinement_objective  num_models  knee_feature_count  num_unified_features  \
# 0  ensemble_validation           5                  19                    53
# 1  ensemble_validation           5                  19                    19
# 2  ensemble_validation           5                  12                    32
# 3  ensemble_validation           5                  12                    12
# 4  ensemble_validation           5                  17                    60
# 5  ensemble_validation           5                  17                    17
#
#    signal_recall  ...  accepted_moves   roc_auc        f1  balanced_accuracy  \
# 0           0.65  ...           112.0  0.932712  0.819048           0.840450
# 1           0.65  ...             NaN  0.947205  0.849558           0.863354
# 2           0.75  ...            56.0  0.948758  0.859504           0.870083
# 3           0.50  ...             NaN  0.965321  0.894737           0.904633
# 4           0.50  ...           187.0  0.922101  0.818182           0.836568
# 5           0.40  ...             NaN  0.940217  0.844037           0.859990
#
#    accuracy  search_max_steps  iterations_run  converged     stop_reason  \
# 0     0.848               500             129       True       converged
# 1     0.864               500             129       True       converged
# 2     0.864               500              67       True       converged
# 3     0.904               500              67       True       converged
# 4     0.840               500             500      False  max_iterations
# 5     0.864               500             500      False  max_iterations
#
#    search_best_score
# 0           0.927370
# 1           0.927370
# 2           0.908319
# 3           0.908319
# 4           0.977370
# 5           0.977370
#
# [6 rows x 22 columns]

# %% [markdown]
# ## Blind-set comparison
#
# The pooled search is compared with the matching fixed-stratified zero-step
# baseline and the prior per-model joint refinement using patience 50 and a
# 500-step maximum.

# %%
pooled = pooled_results.query("method == 'MiSTIC ensemble-pooled search'")
baseline = pd.read_csv(
    repo_root / "validation/Synthetic100_svmSet_forward_fixed_stratified_baseline_results.csv"
).query("method == 'MiSTIC SVM set'")
joint = pd.read_csv(
    repo_root / "validation/Synthetic100_svmSet_forward_500_patience50_fixed_stratified_results.csv"
).query("method == 'MiSTIC SVM set'")

comparison_rows = pd.concat([
    baseline.assign(condition="zero-step baseline"),
    joint.assign(condition="joint per-model search"),
    pooled.assign(condition="ensemble-pooled search"),
], ignore_index=True)
comparison_rows.groupby("condition").agg(
    mean_auc=("roc_auc", "mean"),
    sd_auc=("roc_auc", "std"),
    mean_f1=("f1", "mean"),
    mean_accuracy=("accuracy", "mean"),
    mean_signal_recall=("signal_recall", "mean"),
    mean_union_size=("num_unified_features", "mean"),
    mean_iterations_run=("iterations_run", "mean"),
    mean_accepted_moves=("accepted_moves", "mean"),
).round(4)
# Out:
#                         mean_auc  sd_auc  mean_f1  mean_accuracy  \
# condition
# ensemble-pooled search    0.9345  0.0134   0.8322         0.8507
# joint per-model search    0.9115  0.0224   0.8205         0.8347
# zero-step baseline        0.9249  0.0341   0.8293         0.8427
#
#                         mean_signal_recall  mean_union_size  \
# condition
# ensemble-pooled search              0.6333          48.3333
# joint per-model search              0.6500          51.3333
# zero-step baseline                  0.6500          38.3333
#
#                         mean_iterations_run  mean_accepted_moves
# condition
# ensemble-pooled search             232.0000             118.3333
# joint per-model search             116.6667              68.0000
# zero-step baseline                      NaN               0.0000

# %%
base = baseline.set_index("seed")
new = pooled.set_index("seed")
paired = pd.DataFrame({
    "delta_auc_pooled_minus_baseline": new["roc_auc"] - base["roc_auc"],
    "delta_f1_pooled_minus_baseline": new["f1"] - base["f1"],
    "delta_recall_pooled_minus_baseline": new["signal_recall"] - base["signal_recall"],
    "delta_union_pooled_minus_baseline": new["num_unified_features"] - base["num_unified_features"],
    "iterations_run": new["iterations_run"],
    "stop_reason": new["stop_reason"],
})
pd.concat([paired, pd.DataFrame([paired.select_dtypes("number").mean().rename("mean")])])
# Out:
#       delta_auc_pooled_minus_baseline  delta_f1_pooled_minus_baseline  \
# 0                           -0.001294                       -0.017316
# 1                           -0.004658                        0.027646
# 2                            0.034938                       -0.001490
# mean                         0.009662                        0.002946
#
#       delta_recall_pooled_minus_baseline  delta_union_pooled_minus_baseline  \
# 0                              -0.050000                               12.0
# 1                               0.000000                                4.0
# 2                               0.000000                               14.0
# mean                           -0.016667                               10.0
#
#       iterations_run     stop_reason
# 0              129.0       converged
# 1               67.0       converged
# 2              500.0  max_iterations
# mean           232.0             NaN

# %% [markdown]
# ## Search-objective trajectory

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
for seed in INNER_SEEDS:
    values = pooled_history.query("seed == @seed")
    axes[0].plot(values["step"], values["actual_score"], alpha=0.2, linewidth=0.8)
    axes[0].plot(values["step"], values["best_score"], linewidth=2, label=f"seed {seed} best")
axes[0].set(
    title="Out-of-fold ensemble search score",
    xlabel="Search step", ylabel="Aggregate OOF score",
)
axes[0].legend()

sns.scatterplot(
    data=pooled_history, x="estimated_score", y="actual_score",
    hue="seed", alpha=0.55, ax=axes[1], palette="tab10",
)
limits = [
    min(pooled_history["estimated_score"].min(), pooled_history["actual_score"].min()),
    max(pooled_history["estimated_score"].max(), pooled_history["actual_score"].max()),
]
axes[1].plot(limits, limits, color="black", linestyle="--", linewidth=1)
axes[1].set(
    title="Estimated versus tuned proposal score",
    xlabel="Estimated candidate score", ylabel="Actual tuned score",
)
plt.tight_layout()
